# %%
from astropy.table import Table, vstack
import matplotlib.pyplot as plt
import numpy as np
import pyphot

lib = pyphot.get_library()

# %%
core = 'CO'
layer = 'Hrich'
table = Table()

masses = ['110', '116', '123', '129'] # solar masses (e.g. 1.10 Msun)
for mass in masses:
    # read in the table from the correct file
    path = f'./high_mass/{core}_{mass}_{layer}_0_02.dat'
    temp_table = Table.read(path, format='ascii')

    # put the columns into a pyphot-readable standard
    temp_table.rename_columns(['Teff', 'logg(CGS)'], ['teff', 'logg'])
    #temp_table.remove_columns(['g_1', 'r_1', 'i_1', 'z_1', 'y', 'U', 'B',\
    #                    'V', 'R', 'I', 'J', 'H', 'K', 'FUV', 'NUV'])
    
    mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag', 
                'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag', '2MASS_J_mag', '2MASS_H_mag', '2MASS_Ks_mag', 
                'GALEX_FUV_mag', 'GALEX_NUV_mag']
    temp_table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y',
                                'J', 'H', 'K', 'FUV', 'NUV'], mag_cols)
    
    # now convert from absolute magnitude to surface flux
    for col in mag_cols:
        temp_table[col[:-4]] = (4*np.pi)**-1 * 10**(-0.4*(temp_table[col] + lib[col[:-4]].Vega_zero_mag)) * ((10*3.086775e16) / (6.957e8*temp_table['R/R_sun']))**2
    
    # stack the tables
    table = vstack([table, temp_table])
    print(mass, max(temp_table['teff']), min(temp_table['teff']), max(temp_table['logg']), min(temp_table['logg']))


table.rename_column('R/R_sun', 'Radius')
#table.write('CO_Hrich_Massive.csv', overwrite=True)

plt.scatter(table['teff'], table['logg'])
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('$\log g$')
plt.title('Ultramassive CO Hrich')
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\l'
# <>:36: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_53920/3361174605.py:36: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log g$')
# 110 79217.47582723375 3416.8585469391273 8.8399086 8.7715295
# 116 79683.24282162874 3023.862227104314 8.9581272 8.8976667
# 123 79179.90931178578 3363.496654126076 9.1218046 9.0728359
# 129 79300.69617978985 4759.277192949766 9.3037376 9.2661042
# Text(0.5, 1.0, 'Ultramassive CO Hrich')

# %%
core = 'CO'
layer = 'Hdef'
table = Table()

masses = ['110', '116', '123', '129'] # solar masses (e.g. 1.10 Msun)
for mass in masses:
    # read in the table from the correct file
    path = f'.//high_mass/{core}_{mass}_{layer}_0_02.dat'
    temp_table = Table.read(path, format='ascii')

    # put the columns into a pyphot-readable standard
    temp_table.rename_columns(['Teff', 'logg(CGS)'], ['teff', 'logg'])
    
    mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag', 
                'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag', '2MASS_J_mag', '2MASS_H_mag', '2MASS_Ks_mag', 
                'GALEX_FUV_mag', 'GALEX_NUV_mag']
    temp_table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y',
                                'J', 'H', 'K', 'FUV', 'NUV'], mag_cols)
    
    # now convert from absolute magnitude to surface flux
    for col in mag_cols:
        temp_table[col[:-4]] = (4*np.pi)**-1 * 10**(-0.4*(temp_table[col] + lib[col[:-4]].Vega_zero_mag)) * ((10*3.086775e16) / (6.957e8*temp_table['R/R_sun']))**2
    
    # stack the tables
    table = vstack([table, temp_table])
    print(mass, max(temp_table['teff']), min(temp_table['teff']), max(temp_table['logg']), min(temp_table['logg']))


table.rename_column('R/R_sun', 'Radius')
#table.write('CO_Hdef_Massive.csv', overwrite=True)

plt.scatter(table['teff'], table['logg'])
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('$\log g$')
plt.title('Ultramassive CO Hdef')

8.85, 9.28
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_53920/1755501765.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log g$')
# 110 79897.46496958123 4040.675738481134 8.8431936 8.7890218
# 116 79260.17009321394 4181.422001033554 8.9618759 8.9149192
# 123 79104.64757143418 4114.082534241912 9.1261759 9.0882501
# 129 79187.20238679287 4321.972507845209 9.3102738 9.280276
# (8.85, 9.28)

# %%
core = 'ONe'
layer = 'Hrich'
table = Table()

masses = ['110', '116', '123', '129'] # solar masses (e.g. 1.10 Msun)
for mass in masses:
    # read in the table from the correct file
    path = f'.//high_mass/{core}_{mass}_{layer}_0_02.dat'
    temp_table = Table.read(path, format='ascii')

    # put the columns into a pyphot-readable standard
    temp_table.rename_columns(['Teff', 'logg(CGS)'], ['teff', 'logg'])
    
    mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag', 
                'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag', '2MASS_J_mag', '2MASS_H_mag', '2MASS_Ks_mag', 
                'GALEX_FUV_mag', 'GALEX_NUV_mag']
    temp_table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y',
                                'J', 'H', 'K', 'FUV', 'NUV'], mag_cols)
    
    # now convert from absolute magnitude to surface flux
    for col in mag_cols:
        temp_table[col[:-4]] = (4*np.pi)**-1 * 10**(-0.4*(temp_table[col] + lib[col[:-4]].Vega_zero_mag)) * ((10*3.086775e16) / (6.957e8*temp_table['R/R_sun']))**2
    
    # stack the tables
    table = vstack([table, temp_table])
    print(mass, max(temp_table['teff']), min(temp_table['teff']), max(temp_table['logg']), min(temp_table['logg']))


table.rename_column('R/R_sun', 'Radius')
#table.write('ONe_Hrich_Massive.csv', overwrite=True)

plt.scatter(table['teff'], table['logg'])
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('$\log g$')
plt.title('Ultramassive ONe Hrich')
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_53920/287273197.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log g$')
# /tmp/ipykernel_53920/287273197.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log g$')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 12
#       9 temp_table = Table.read(path, format='ascii')
#      11 # put the columns into a pyphot-readable standard
# ---> 12 temp_table.rename_columns(['Teff', 'logg(CGS)'], ['teff', 'logg'])
#      14 mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag',
#      15             'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag', '2MASS_J_mag', '2MASS_H_mag', '2MASS_Ks_mag',
#      16             'GALEX_FUV_mag', 'GALEX_NUV_mag']
#      17 temp_table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y',
#      18                             'J', 'H', 'K', 'FUV', 'NUV'], mag_cols)
#
# File ~/miniconda3/envs/stark/lib/python3.12/site-packages/astropy/table/table.py:3144, in Table.rename_columns(self, names, new_names)
#    3139     raise ValueError(
#    3140         "input 'names' and 'new_names' list arguments must be the same length"
#    3141     )
#    3143 for name, new_name in zip(names, new_names):
# -> 3144     self.rename_column(name, new_name)
#
# File ~/miniconda3/envs/stark/lib/python3.12/site-packages/astropy/table/table.py:3093, in Table.rename_column(self, name, new_name)
#    3057 """
#    3058 Rename a column.
#    3059
#    (...)
#    3090       2   4   6
#    3091 """
#    3092 if name not in self.keys():
# -> 3093     raise KeyError(f"Column {name} does not exist")
#    3095 self.columns[name].info.name = new_name
#
# KeyError: 'Column Teff does not exist'

# %%
core = 'ONe'
layer = 'Hdef'
table = Table()

masses = ['110', '116', '123', '129'] # solar masses (e.g. 1.10 Msun)
for mass in masses:
    # read in the table from the correct file
    path = f'.//high_mass/{core}_{mass}_{layer}_0_02.dat'
    temp_table = Table.read(path, format='ascii')

    # put the columns into a pyphot-readable standard
    temp_table.rename_columns(['Teff', 'logg(CGS)'], ['teff', 'logg'])

    mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag', 
                'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag', '2MASS_J_mag', '2MASS_H_mag', '2MASS_Ks_mag', 
                'GALEX_FUV_mag', 'GALEX_NUV_mag']
    temp_table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y',
                                'J', 'H', 'K', 'FUV', 'NUV'], mag_cols)

    # now convert from absolute magnitude to surface flux
    for col in mag_cols:
        temp_table[col[:-4]] = (4*np.pi)**-1 * 10**(-0.4*(temp_table[col] + lib[col[:-4]].Vega_zero_mag)) * ((10*3.086775e16) / (6.957e8*temp_table['R/R_sun']))**2
    
    # stack the tables
    table = vstack([table, temp_table])

    print(mass, max(temp_table['teff']), min(temp_table['teff']), max(temp_table['logg']), min(temp_table['logg']))

table.rename_column('R/R_sun', 'Radius')
#table.write('ONe_Hdef_Massive.csv', overwrite=True)

plt.scatter(table['teff'], table['logg'])
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('$\log g$')
plt.title('Ultramassive ONe Hdef')
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_336818/137603645.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log g$')
# 110 78848.23932291634 4008.5933345748745 8.854817 8.798564
# 116 79342.5218275885 4000.2579777215406 8.9853381 8.9301551
# 123 79225.68447655397 4222.192208709281 9.1630382 9.0985394
# 129 79774.85068590299 4005.0874202477985 9.383884 9.317871
# Text(0.5, 1.0, 'Ultramassive ONe Hdef')

# %%
import pandas as pd

table = pd.read_csv('allwd_Hrich.csv')

plt.scatter(table['teff'], table['R(Rsun)']*109.75, c=table['core'].map({'CO': 'blue', 'ONe': 'red', 'He': 'green'}), s = 10)
plt.axvline(17792.467364139906, c = 'k')
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('Radius [$R_\oplus$]')
#plt.title('La Plata Grid Used In Raddi+2022')
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\o'
# <>:8: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_23386/659393268.py:8: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('Radius [$R_\oplus$]')
# Text(0, 0.5, 'Radius [$R_\\oplus$]')

# %%
plt.scatter(table['teff'], table['mWD'], c=table['core'].map({'CO': 'blue', 'ONe': 'red', 'He': 'green'}), s = 10)
plt.axvline(17792.467364139906, c = 'k')
plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('Radius [$R_\oplus$]')
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\o'
# <>:4: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_23386/2680506316.py:4: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('Radius [$R_\oplus$]')
# Text(0, 0.5, 'Radius [$R_\\oplus$]')

# %%
table = Table.read('DAwhitedwarfsZ0.02.dat', format='ascii')

# %%
table.rename_columns(['Log(g)'], ['logg'])

# %%
table['teff'] = 10**table['log(teff)']

mag_cols = ['Gaia_G_mag', 'Gaia_BP_mag', 'Gaia_RP_mag', 'SDSS_u_mag', 'SDSS_g_mag', 'SDSS_r_mag', 'SDSS_i_mag', 'SDSS_z_mag', 
            'PS1_g_mag', 'PS1_r_mag', 'PS1_i_mag', 'PS1_z_mag', 'PS1_y_mag']
table.rename_columns(['G3', 'Bp3', 'Rp3', 'u', 'g', 'r', 'i', 'z', 'PS1_g', 'PS1_r', 'PS1_i', 'PS1_z', 'PS1_y'], mag_cols)

# now convert from absolute magnitude to surface flux
for col in mag_cols:
    table[col[:-4]] = (4*np.pi)**-1 * 10**(-0.4*(table[col] + lib[col[:-4]].Vega_zero_mag)) * ((10*3.086775e16) / (6.957e8*table['R(Rsun)']))**2

# %%
table[0:3]
# Out:
# <Table length=3>
#   logg  log(teff)   mWD   ...       PS1_z              PS1_y
# float64  float64  float64 ...      float64            float64
# ------- --------- ------- ... ------------------ -----------------
#     7.0       4.9   0.496 ... 10084123.025622768 6510040.154894401
#     7.0      4.88   0.488 ...  9669659.971698359  6245924.56281188
#     7.0      4.86   0.481 ...   9351225.69215411 6035789.299720631

# %%
table.write('allwd_Hrich.csv', overwrite=True)
